# %% [markdown]
# Tests

# %%
import unittest

solution = [{'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 3,
  'Hornbill': 4,
  'Boar': 4,
  'Meerkat': 4},
 {'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 3,
  'Hornbill': 4,
  'Boar': 1,
  'Meerkat': 1},
 {'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 2,
  'Hornbill': 3,
  'Boar': 3,
  'Meerkat': 3},
 {'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 2,
  'Hornbill': 3,
  'Boar': 4,
  'Meerkat': 4},
 {'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 2,
  'Hornbill': 3,
  'Boar': 1,
  'Meerkat': 1},
 {'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 2,
  'Hornbill': 4,
  'Boar': 3,
  'Meerkat': 3},
 {'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 2,
  'Hornbill': 4,
  'Boar': 4,
  'Meerkat': 4},
 {'EvilLion': 2,
  'Antelope': 4,
  'Lion': 1,
  'Hyena': 2,
  'Hornbill': 4,
  'Boar': 1,
  'Meerkat': 1}
           ]

class TestZoo(unittest.TestCase):
    def test_all_solutions_valid(self):
        for submitted in solve_zoo():
            self.assertIn(submitted, solution)
    def test_all_valid_solutions_submitted(self):
        for s in solution:
            self.assertIn(s, solve_zoo())
    def test_num_solutions(self):
        self.assertEqual(len(solve_zoo()), len(solution))
    def test_where_meerkat(self):
        self.assertEqual(set(where_can_i_put('Meerkat')), set([1,3,4]))
    def test_where_evillion(self):
        self.assertEqual(where_can_i_put('EvilLion'), [2])
    def test_invalid_input(self):
        self.assertRaises(BaseException, where_can_i_put, "xxx")

def test_zoo():
    print("NOTE: The test test_num_solutions will always fail if either of the two previous tests fail")
    print("Do not penalize twice -- it is run just to compare number of solutions generated to the correct number")
    unittest.main(argv=[''], verbosity=2, exit=False)
